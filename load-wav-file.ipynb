# %%
    import sys
    # !{sys.executable} -m pip install scipy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4/58.4 MB 7.3 MB/s eta 0:00:00m eta 0:00:010:00:01m
# ...

# %% [markdown]
# Source : https://stackoverflow.com/questions/23377665/python-scipy-fft-wav-files

# %%
import matplotlib.pyplot as plt
from scipy.fftpack import fft
from scipy.io import wavfile # get the api

#rate, data = wavfile.read('stereo-unsigned-8-bit-data.wav') # load the data
rate, data = wavfile.read('pcm0844s.wav') # load the data

print(len(data))
print(rate)

a = data.T[0] # this is a two channel soundtrack, I get the first track
b=[(ele/2**8.)*2-1 for ele in a] # this is 8-bit track, b is now normalized on [-1,1)

plt.plot(a,'r') 
plt.show()

c = fft(b) # calculate fourier transform (complex numbers list)
d = len(c)/2  # you only need half of the fft list (real signal symmetry)

plt.plot(abs(c[:(int(d-1))]),'r') 
plt.show()
# Out:
# 294909
# 44100
